# %%
import pandas as pd

# %%
lexique = pd.read_excel('Lexique - Data Analyst.xlsx')
cash_requests = pd.read_csv ('extract - cash request - data analyst.csv')
fees = pd.read_csv ('extract - fees - data analyst - .csv')

# %%
#Start to explore the files

display(lexique)
# Out:
#       Column name                                        Description
# 0              id                        Unique ID of the fee object
# 1            type  Type of fee\nPossible values are :\n\n- instan...
# 2          status  Status of the fees (= does the fees was succes...
# 3        category  Describe the reason of the incident fee.\n\n2 ...
# 4          reason                             Description of the fee
# ...           ...                                                ...
# 16370           0                                                NaN
# 16371           0                                                NaN
# 16372           0                                                NaN
# 16373           0                                                NaN
# 16374           0                                                NaN
#
# [16375 rows x 2 columns]

# %%
lexique.head(10)
# Out:
#   Column name                                        Description
# 0          id                        Unique ID of the fee object
# 1        type  Type of fee\nPossible values are :\n\n- instan...
# 2      status  Status of the fees (= does the fees was succes...
# 3    category  Describe the reason of the incident fee.\n\n2 ...
# 4      reason                             Description of the fee
# 5  created_at                    Timestamp of the fee's creation
# 6  updated_at       Timestamp of the latest fee's details update
# 7     paid_at                     Timestamp of the fee's payment
# 8   from_date  Apply only to postpone fees. Initial date of r...
# 9     to_date  Apply only to postpone fees. New date of reimb...

# %%
lexique.tail ()
# Out:
#       Column name Description
# 16370           0         NaN
# 16371           0         NaN
# 16372           0         NaN
# 16373           0         NaN
# 16374           0         NaN

# %%
lexique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16375 entries, 0 to 16374
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Column name  16003 non-null  object
#  1   Description  13 non-null     object
# dtypes: object(2)
# memory usage: 256.0+ KB

# %% [markdown]
# Reviewing the table infomation, the information is not balanced; we have total of 16.375 rows, 16.003 it has values and only 13 has the desception. For a table to be consistent, the information should be balanced.

# %%
display(cash_requests.)
# Out:
#           id  amount             status                     created_at  \
# 0          5   100.0           rejected  2019-12-10 19:05:21.596873+00
# 1         70   100.0           rejected   2019-12-10 19:50:12.34778+00
# 2          7   100.0           rejected   2019-12-10 19:13:35.82546+00
# 3         10    99.0           rejected  2019-12-10 19:16:10.880172+00
# 4       1594   100.0           rejected  2020-05-06 09:59:38.877376+00
# ...      ...     ...                ...                            ...
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                           updated_at  user_id                   moderated_at  \
# ...

# %%
display(cash_requests.head())
# Out:
#      id  amount    status                     created_at  \
# 0     5   100.0  rejected  2019-12-10 19:05:21.596873+00
# 1    70   100.0  rejected   2019-12-10 19:50:12.34778+00
# 2     7   100.0  rejected   2019-12-10 19:13:35.82546+00
# 3    10    99.0  rejected  2019-12-10 19:16:10.880172+00
# 4  1594   100.0  rejected  2020-05-06 09:59:38.877376+00
#
#                       updated_at  user_id                   moderated_at  \
# 0   2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1  2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2  2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# 3  2019-12-18 14:26:18.136163+00    761.0  2019-12-18 14:26:18.128407+00
# 4   2020-05-07 09:21:55.34008+00   7686.0  2020-05-07 09:21:55.320193+00
#
#    deleted_account_id             reimbursement_date  \
# 0                 NaN  2020-01-09 19:05:21.596363+00
# 1                 NaN   2020-01-09 19:50:12.34778+00
# ...

# %%
cash_requests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          23970 non-null  int64
#  1   amount                      23970 non-null  float64
#  2   status                      23970 non-null  object
#  3   created_at                  23970 non-null  object
#  4   updated_at                  23970 non-null  object
#  5   user_id                     21867 non-null  float64
#  6   moderated_at                16035 non-null  object
#  7   deleted_account_id          2104 non-null   float64
#  8   reimbursement_date          23970 non-null  object
#  9   cash_request_received_date  16289 non-null  object
#  10  money_back_date             16543 non-null  object
#  11  transfer_type               23970 non-null  object
#  12  send_at                     16641 non-null  object
# ...

# %% [markdown]
# #  cash_requests.info() : Multiple date column (created_at, updated_at, moderated_at, reimbursement_date, cash_request_received_date, money_back_date) are in
# #   text format, soy they need to be converted to (datetime). Otherwise , "user_id" when compared to "amount" column we see taht users are missing
# # they need have a lineal conection. In addition, the user_id column appears in decimal format.

# %%
fees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21061 entries, 0 to 21060
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21061 non-null  int64
#  1   cash_request_id  21057 non-null  float64
#  2   type             21061 non-null  object
#  3   status           21061 non-null  object
#  4   category         2196 non-null   object
#  5   total_amount     21061 non-null  float64
#  6   reason           21061 non-null  object
#  7   created_at       21061 non-null  object
#  8   updated_at       21061 non-null  object
#  9   paid_at          15531 non-null  object
#  10  from_date        7766 non-null   object
#  11  to_date          7766 non-null   object
#  12  charge_moment    21061 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.1+ MB

# %% [markdown]
# In the fees df several columns related to dates—such as created_at, updated_at, paid_at, from_date, to_date, and charge_moment—appear in text format (object).

# %%
cash_requests.dropna(subset=['user_id'], inplace=True)
# Out:
#           id  amount             status                     created_at  \
# 0          5   100.0           rejected  2019-12-10 19:05:21.596873+00
# 1         70   100.0           rejected   2019-12-10 19:50:12.34778+00
# 2          7   100.0           rejected   2019-12-10 19:13:35.82546+00
# 3         10    99.0           rejected  2019-12-10 19:16:10.880172+00
# 4       1594   100.0           rejected  2020-05-06 09:59:38.877376+00
# ...      ...     ...                ...                            ...
# 23964  16834   100.0         money_back  2020-09-19 07:37:14.351567+00
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                           updated_at  user_id                   moderated_at  \
# ...

# %%
#USE .nunique to se how many different values each column

cash_requests.nunique()
# Out:
# id                            21867
# amount                           40
# status                            7
# created_at                    21867
# updated_at                    21867
# user_id                       10798
# moderated_at                  14109
# deleted_account_id                1
# reimbursement_date             3631
# cash_request_received_date      311
# money_back_date               11723
# transfer_type                     2
# send_at                       15542
# recovery_status                   4
# reco_creation                  3140
# reco_last_update               3140
# dtype: int64

# %%
# There ar more "id" 21.867 than "user_id", this means that some users are appear multiple time. Duplicates

# %%
fees.nunique()
# Out:
# id                 21061
# cash_request_id    12933
# type                   3
# status                 4
# category               2
# total_amount           2
# reason             15149
# created_at         21026
# updated_at         21061
# paid_at            15529
# from_date           1084
# to_date             1560
# charge_moment          2
# dtype: int64

# %%
cash_requests.columns[cash_requests.columns.duplicated()] #Duplicate columns?
fees.columns[fees.columns.duplicated()]
# Out:
# Index([], dtype='object')

# %%
fees.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False])
